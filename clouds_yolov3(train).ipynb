# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/clouds_yolov3'
# Out:
# backup	clouds	clouds_weights	clouds.zip  darknet

# %%
#!unzip '/content/drive/My Drive/clouds_yolov3/clouds.zip' -d '/content/drive/My Drive/clouds_yolov3/'

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/clouds_yolov3/darknet'

# %%
# %cd /content/drive/My Drive/clouds_yolov3/darknet
# Out:
# /content/drive/My Drive/clouds_yolov3/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       README.md
# backup		darknet_images.py	json_mjpeg_streams.sh  results
# build		darknet.py		LICENSE		       scripts
# build.ps1	darknet_video.py	Makefile	       src
# cfg		data			net_cam_v3.sh	       vcpkg.json
# cmake		image_yolov3.sh		net_cam_v4.sh	       video_yolov3.sh
# CMakeLists.txt	image_yolov4.sh		obj		       video_yolov4.sh

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd /content/drive/My Drive/clouds_yolov3
# Out:
# /content/drive/My Drive/clouds_yolov3

# %%
# !python clouds/creating-files-data-and-name.py

# %%
# !python clouds/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
#%cd /content/drive/My Drive/clouds_yolov3/clouds_weights

# %%
#!wget 'https://pjreddie.com/media/files/darknet53.conv.74'

# %%
# %cd /content/drive/My Drive/clouds_yolov3
# Out:
# /content/drive/My Drive/clouds_yolov3

# %%
# !darknet/darknet detector train clouds/labelled_data.data darknet/cfg/yolov3_custom.cfg clouds_weights/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 141641, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.805742), count: 3, class_loss = 0.684790, iou_loss = 0.336629, total_loss = 1.021419
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001116, iou_loss = 0.000000, total_loss = 0.001116
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
#  total_bbox = 141644, rewritten_bbox = 0.000000 %
# ...
